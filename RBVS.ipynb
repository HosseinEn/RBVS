# %%
! rm -rf /kaggle/working/*
! git clone -b kaggle 'https://oauth2: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@github.com/HosseinEn/computer-vision-RBVS.git'
# Out:
# Cloning into 'computer-vision-RBVS'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 35 (delta 13), reused 31 (delta 9), pack-reused 0
# Unpacking objects: 100% (35/35), 25.30 KiB | 470.00 KiB/s, done.

# %%
# %%capture
# !wget https://staffnet.kingston.ac.uk/~ku15565/CHASE_DB1/assets/CHASEDB1.zip
# !unzip -d /kaggle/working/CHASEDB1 /kaggle/working/CHASEDB1.zip

# %%
# %%capture
# !/kaggle/working/computer-vision-RBVS/clean.sh

# %%
! python3 /kaggle/working/computer-vision-RBVS/my_dataset.py
! python3 /kaggle/working/computer-vision-RBVS/main.py --model_type=R2U_Net
# Out:
# Namespace(train_ratio=0.6, valid_ratio=0.2, test_ratio=0.2, origin_data_path='/kaggle/working/CHASEDB1', origin_GT_path='/kaggle/working/CHASEDB1_GT', train_path='./dataset/train/', train_GT_path='./dataset/train_GT/', valid_path='./dataset/valid/', valid_GT_path='./dataset/valid_GT/', test_path='./dataset/test/', test_GT_path='./dataset/test_GT/')
# Create path - ./dataset/train/
# Create path - ./dataset/train_GT/
# Create path - ./dataset/valid/
# Create path - ./dataset/valid_GT/
# Create path - ./dataset/test/
# Create path - ./dataset/test_GT/
# Create path - /kaggle/working/CHASEDB1_GT
#
# Num of train set :  16
#
# Num of valid set :  5
#
# Num of test set :  7
# Producing train set: |██████████████████████████████████████████████████| 100.0% Complete
# Producing valid set: |██████████████████████████████████████████████████| 100.0% Complete
# Producing test set: |██████████████████████████████████████████████████| 100.0% Complete
# ...
