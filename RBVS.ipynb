# %%
# %%capture

! git clone 'https://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@computer-vision-RBVS.git'
# !git clone https://github.com/LeeJunHyun/Image_Segmentation.git

# !wget https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task1-2_Training_Input.zip
# !wget https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task1_Training_GroundTruth.zip

# !unzip /content/ISIC2018_Task1-2_Training_Input.zip
# !unzip /content/ISIC2018_Task1_Training_GroundTruth.zip

# !mkdir /content/dataset
# !mv /content/ISIC2018_Task1-2_Training_Input /content/dataset/
# !mv /content/ISIC2018_Task1_Training_GroundTruth /content/dataset/
# ! python3 /content/Image_Segmentation/dataset.py --origin_data_path=/content/dataset/ISIC2018_Task1-2_Training_Input \
#  --origin_GT_path=/content/dataset/ISIC2018_Task1_Training_GroundTruth


# !wget https://staffnet.kingston.ac.uk/~ku15565/CHASE_DB1/assets/CHASEDB1.zip
# !unzip -d /kaggle/working/CHASEDB1 /kaggle/working/CHASEDB1.zip
# Out:
# Cloning into 'Image_Segmentation'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 54 (delta 0), reused 1 (delta 0), pack-reused 51
# Receiving objects: 100% (54/54), 265.65 KiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
! cp '/content/drive/MyDrive/Colab Notebooks/CV/my_data_loader.py' /content/Image_Segmentation
! cp '/content/drive/MyDrive/Colab Notebooks/CV/my_dataset.py' /content/Image_Segmentation
! cp  '/content/drive/MyDrive/Colab Notebooks/CV/my_dataset.py' /content/clean.sh

# %%
! cp  '/content/drive/MyDrive/Colab Notebooks/CV/clean.sh' /content/

# %%
! python3 /content/Image_Segmentation/my_dataset.py
! python3 /content/Image_Segmentation/main.py --model_type=R2U_Net
# Out:
# Namespace(train_ratio=0.6, valid_ratio=0.2, test_ratio=0.2, origin_data_path='/content/CHASEDB1', origin_GT_path='/content/CHASEDB1_GT', train_path='./dataset/train/', train_GT_path='./dataset/train_GT/', valid_path='./dataset/valid/', valid_GT_path='./dataset/valid_GT/', test_path='./dataset/test/', test_GT_path='./dataset/test_GT/')
# Create path - ./dataset/train/
# Create path - ./dataset/train_GT/
# Create path - ./dataset/valid/
# Create path - ./dataset/valid_GT/
# Create path - ./dataset/test/
# Create path - ./dataset/test_GT/
# Create path - /content/CHASEDB1_GT
#
# Num of train set :  16
#
# Num of valid set :  5
#
# Num of test set :  7
# Producing train set: |██████████████████████████████████████████████████| 100.0% Complete
# Producing valid set: |██████████████████████████████████████████████████| 100.0% Complete
# Producing test set: |██████████████████████████████████████████████████| 100.0% Complete
# ...

# %%
# !git clone https://github.com/Libo-Xu/DRIVE--Digital-Retinal-Images-for-Vessel-Extraction.git
# Out:
# Cloning into 'DRIVE--Digital-Retinal-Images-for-Vessel-Extraction'...
# remote: Enumerating objects: 188, done.
# remote: Total 188 (delta 0), reused 0 (delta 0), pack-reused 188
# Receiving objects: 100% (188/188), 61.54 MiB | 30.91 MiB/s, done.

# %%
# %%capture
# !sh /content/clean.sh

# %%
# !ssh-keygen -t rsa -b 4096 -f ~/.ssh/id_rsa -N ''
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !cat ~/.ssh/id_rsa.pub
# !ssh -T git@github.com
# !git config --global user.email 'Hosseinenshaei@stu.nit.ac.ir'
# !git config --global user.username 'HosseinEn'
# Out:
# Generating public/private rsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:OYLcl3La/cfpSOtCMRyRsvLhRW1lSIru8cw/tdAERtk root@eefcabc932e9
# The key's randomart image is:
# +---[RSA 4096]----+
# |          .*o=o  |
# |        ..+.B.E  |
# |        .=.+ .   |
# |   . o..oo=   .  |
# |    o ++So o o   |
# |       OoB. . o  |
# |      . o.= .+ o |
# |          .+.o=  |
# |           o*+.  |
# +----[SHA256]-----+

# %%
# !git clone git@github.com:HosseinEn/computer-vision-RBVS.git
# Out:
# Hi HosseinEn! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git -C /content/computer-vision-RBVS/ pull
# Out:
# /content
# Already up to date.
